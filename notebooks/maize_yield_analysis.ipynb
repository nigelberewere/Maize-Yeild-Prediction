# %% [markdown]
# # Maize Yield Exploratory Data Analysis
#
# This notebook explores relationships between rainfall, temperature, fertilizer use, and maize yield in the synthetic Zimbabwe dataset. Replace with real data when available.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/zimbabwe_maize_yield.csv')
df.head()

# %%
# Basic checks
df.info()
df.describe()
df.isnull().sum()

# %%
sns.pairplot(df[['Rainfall_mm', 'Average_Temperature_C', 'Fertilizer_kg_per_ha', 'Yield_kg_per_ha']])
plt.show()
